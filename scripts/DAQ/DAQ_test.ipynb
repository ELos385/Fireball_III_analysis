# %%
import os, sys
from pathlib import Path
import matplotlib.pyplot as plt 

# 1. import the Experiment object from LAMP 
from LAMP import Experiment

ROOT_FOLDER = str(Path.cwd().parent.parent) #Path.cwd().parent.parent#Path(__file__).resolve().parents[1] # absolute path to the experiment config files and other subfolders; 2 directories up in this case (assuming script in in ./scripts/eSpec/script.py)
sys.path.append(ROOT_FOLDER)
# import diagnostics.ESpec_
ex = Experiment(ROOT_FOLDER)
# Out:
# Using (User) DAQ: Fireball_DAQ
# Adding (User) Diagnostic: HRM5 [ESpec_]
# Adding (User) Diagnostic: HRM6 [ESpec_]
# Adding (User) Diagnostic: Template [Template]
# Adding (User) Diagnostic: SCOPE1 [BDot]
# Adding (User) Diagnostic: SCOPE2 [BDot]

# %%
template = ex.get_diagnostic('Template')

print(template.config)
print(ex.config)
# Out:
# {'type': 'Template', 'data_folder': '/test/', 'data_stem': '', 'data_type': 'asc', 'data_ext': '.asc', 'calib_subfolder': '/', 'calib_file': 'HRM6_calibs.toml', 'name': 'Template'}
# {'setup': {'DAQ': 'Fireball_DAQ'}, 'paths': {'calibs_folder': './calibs/', 'user_diagnostics': 'diagnostics.', 'user_DAQs': 'DAQs.', 'data_folder': '/eos/project/h/hiradmat/HRMT Experiments/2025/HRMT68 - FIREBALL 3/FB3 repository/HRMT68_data/', 'root': PosixPath('/eos/home-i03/m/mmeloper/SWAN_projects/Fireball_III_analysis'), 'local_config': PosixPath('/eos/home-i03/m/mmeloper/SWAN_projects/Fireball_III_analysis/local.toml'), 'global_config': PosixPath('/eos/home-i03/m/mmeloper/SWAN_projects/Fireball_III_analysis/global.toml')}}

# %%
# 5. plot some processed data
#devices[device].get_proc_shot(shot_dict, calib_id=calib_ids[device])
# shot_dict = {'timeframe': ['20260212','20260218']}
# shot_dict = {'timeframe': ['20260212','20260218']}
shot_dict = {'filename': 'test.asc'}
shot_data = template.get_proc_shot(shot_dict)#, calib_id=calib_ids[device], debug=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 6
#       1 # 5. plot some processed data
#       2 #devices[device].get_proc_shot(shot_dict, calib_id=calib_ids[device])
#       3 # shot_dict = {'timeframe': ['20260212','20260218']}
#       4 # shot_dict = {'timeframe': ['20260212','20260218']}
#       5 shot_dict = {'filename': 'test.asc'}
# ----> 6 shot_data = template.get_proc_shot(shot_dict)#, calib_id=calib_ids[device], debug=True)
#
# File /eos/home-i03/m/mmeloper/mamba/envs/FBIII/lib/python3.12/site-packages/LAMP/diagnostic.py:221, in Diagnostic.get_proc_shot(self, shot_dict, calib_id, debug)
#     217     self.calib_dict = self.get_calib(calib_id)
#     218 else:
#     219     # if not self.calib_dict or not len(self.calib_dict):
#     220     #     self.calib_dict = self.get_calib(shot_dict)
# --> 221     self.calib_dict = self.get_calib(shot_dict)
#     223 # TO DO: check if image type, and if not, skip this... although you probably won't call this function if not image?
#     224 # do standard image calibration. Transforms, background, ROIs etc.
#     225 img, x, y = self.run_img_calib(shot_dict, debug=debug)
#
# File /eos/home-i03/m/mmeloper/mamba/envs/FBIII/lib/python3.12/site-packages/LAMP/diagnostic.py:66, in Diagnostic.get_calib(self, calib_id, no_proc)
#      64 if isinstance(calib_id, dict):
#      65     shot_dict = calib_id
# ---> 66     shot_time = self.DAQ.build_time_point(shot_dict)
#      67     # are we already using the correct calibration? Then return dict so we don't keep loading
#      68     if shot_time >= self.calib_start and shot_time <= self.calib_end:
#
# AttributeError: 'Fireball_DAQ' object has no attribute 'build_time_point'

# %%
# shot_data[0][:,0]
fig = plt.plot(shot_data[0][:,0], shot_data[0][:,800])
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # shot_data[0][:,0]
# ----> 2 fig = plt.plot(shot_data[0][:,0], shot_data[0][:,800])
#       3 #plt.show()
#
# NameError: name 'shot_data' is not defined
